# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we summarize the tools and techniques used in data science. We also provide examples of code, libraries, and tools frequently applied in data science workflows.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala
# - Java
# - C++
# - Js
# - php
# - go
# - ruby
# - visual basics

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - ggplot2
# - plotty
# - Seaborn
# - Keras
# - pytorch
# - vegas
# - bigdl
# - creta

# %% [markdown]
# ## Data Science Tools
#
# | Tool          | Category            |
# |---------------|---------------------|
# | Jupyter Notebook | IDE / Notebook   |
# | RStudio       | IDE                 |
# | Apache Spark  | Big Data Processing |
# | TensorFlow    | Machine Learning    |
# | Tableau       | Visualization       |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are some examples of basic arithmetic expressions in Python.

# %%
# Multiply and add numbers
a = 5 * 4
b = 10 + 20
a, b
# Out:
# (20, 30)

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
hours
# Out:
# 2.0

# %% [markdown]
# ## Objectives
# - List popular languages for data science
# - List commonly used libraries in data science
# - Present data science tools
# - Demonstrate basic arithmetic operations in Python

# %% [markdown]
# ## Author
# Dua Noor
